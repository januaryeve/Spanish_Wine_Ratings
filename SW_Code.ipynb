# %% [markdown]
# # Riojas: Does Body Affect Rating?

# %% [markdown]
# https://www.kaggle.com/datasets/fedesoriano/spanish-wine-quality-dataset?resource=download

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('wines_SPA_original.csv')
df.head(10)
# Out:
#           winery                            wine  year  rating  num_reviews
# 0  Teso La Monja                           Tinto  2013     4.9           58  \
# 1         Artadi                   Vina El Pison  2018     4.9           31
# 2   Vega Sicilia                           Unico  2009     4.8         1793
# 3   Vega Sicilia                           Unico  1999     4.8         1705
# 4   Vega Sicilia                           Unico  1996     4.8         1309
# 5   Vega Sicilia                           Unico  1998     4.8         1209
# 6   Vega Sicilia                           Unico  2010     4.8         1201
# 7   Vega Sicilia                           Unico  1995     4.8          926
# 8   Vega Sicilia  Unico Reserva Especial Edicion  2015     4.8          643
# 9   Vega Sicilia                           Unico  2011     4.8          630
#
#   country            region   price                  type  body  acidity
# ...

# %%
len(df)
# Out:
# 7500

# %%
print(df.value_counts('winery'))
# Out:
# winery
# Contino                             457
# Artadi                              261
# La Rioja Alta                       254
# Sierra Cantabria                    237
# Matarromera                         232
#                                    ...
# Gallina de Piel                       1
# Galindo San Millan                    1
# Freixenet                             1
# Francisco Garcia Perez                1
# l'Infernal Combier Fischer Gerin      1
# Name: count, Length: 480, dtype: int64

# %%
print(df.value_counts('region'))
# Out:
# region
# Rioja                  2440
# Ribera del Duero       1413
# Priorato                686
# Toro                    300
# Vino de Espana          263
#                        ...
# Binissalem-Mallorca       1
# Valdejalon                1
# Arribes                   1
# Murcia                    1
# Abona                     1
# Name: count, Length: 76, dtype: int64

# %%
df2 = pd.read_csv('wines_SPA_riojas.csv')
df2.head(10)
# Out:
#           winery                            wine  year  rating  num_reviews
# 0  Teso La Monja                           Tinto  2013     4.9           58  \
# 1         Artadi                   Vina El Pison  2018     4.9           31
# 2   Vega Sicilia                           Unico  2009     4.8         1793
# 3   Vega Sicilia                           Unico  1999     4.8         1705
# 4   Vega Sicilia                           Unico  1996     4.8         1309
# 5   Vega Sicilia                           Unico  1998     4.8         1209
# 6   Vega Sicilia                           Unico  2010     4.8         1201
# 7   Vega Sicilia                           Unico  1995     4.8          926
# 8   Vega Sicilia  Unico Reserva Especial Edicion  2015     4.8          643
# 9   Vega Sicilia                           Unico  2011     4.8          630
#
#   country            region   price                  type  body  acidity
# ...

# %%
df2.drop(['num_reviews'], axis=1, inplace=True)
df2.head(10)
# Out:
#           winery                            wine  year  rating
# 0  Teso La Monja                           Tinto  2013     4.9  \
# 1         Artadi                   Vina El Pison  2018     4.9
# 2   Vega Sicilia                           Unico  2009     4.8
# 3   Vega Sicilia                           Unico  1999     4.8
# 4   Vega Sicilia                           Unico  1996     4.8
# 5   Vega Sicilia                           Unico  1998     4.8
# 6   Vega Sicilia                           Unico  2010     4.8
# 7   Vega Sicilia                           Unico  1995     4.8
# 8   Vega Sicilia  Unico Reserva Especial Edicion  2015     4.8
# 9   Vega Sicilia                           Unico  2011     4.8
#
#              region   price                  type  body  acidity
# 0              Toro  995.00              Toro Red   5.0      3.0
# 1    Vino de Espana  313.50           Tempranillo   4.0      2.0
# 2  Ribera del Duero  324.95  Ribera Del Duero Red   5.0      3.0
# ...

# %% [markdown]
# # TODO:
#
# Next step is to pull only the wines from the Rioja region. Possibly create a loop that displays only rioja
